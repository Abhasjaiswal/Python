# %%
import pandas as pd
import numpy as np

# %%
csv_path=("new_york_listings_2024.csv")
df=pd.read_csv(csv_path)
df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20753            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20754             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20755            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20756  782661008019550832  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20757  566029911248687183  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# 0        7130382              Walter            Brooklyn        Clinton Hill
# 1       51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2      528871354              Joshua           Manhattan             Chelsea
# 3       19902271  John And Catherine           Manhattan  Washington Heights
# 4       61391963      Stay With Vibe           Manhattan         Murray Hill
# ...          ...                 ...                 ...                 ...
# 20753  186680487             Henry D           Manhattan     Lower East Side
# 20754    3237504               Aspen           Manhattan   Greenwich Village
# 20755  304317395                Jeff           Manhattan      Hell's Kitchen
# 20756  163083101             Marissa           Manhattan           Chinatown
# 20757   93827372             Glenroy              Queens            Rosedale
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      40.683710 -73.964610     Private room   55.0              30
# 1      40.766610 -73.988100  Entire home/apt  144.0              30
# 2      40.750764 -73.994605  Entire home/apt  187.0               2
# 3      40.835600 -73.942500     Private room  120.0              30
# 4      40.751120 -73.978600  Entire home/apt   85.0              30
# ...          ...        ...              ...    ...             ...
# 20753  40.711380 -73.991560     Private room   45.0              30
# 20754  40.730580 -74.000700  Entire home/apt  105.0              30
# 20755  40.757350 -73.993430  Entire home/apt  299.0              30
# 20756  40.713750 -73.991470  Entire home/apt  115.0              30
# 20757  40.658874 -73.728651     Private room  102.0               1
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      3  2015-12-20               0.03
# 1                      9  2023-05-01               0.24
# 2                      6  2023-12-18               1.67
# 3                    156  2023-09-17               1.38
# 4                     11  2023-12-03               0.24
# ...                  ...         ...                ...
# 20753                124  2023-09-29               1.81
# 20754                 56  2023-07-01               0.48
# 20755                 60  2023-12-08               2.09
# 20756                  7  2023-09-17               0.91
# 20757                 63  2023-12-10               4.50
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1                 0
# 1                                 139               364
# 2                                   1               343
# 3                                   2               363
# 4                                 133               335
# ...                               ...               ...
# 20753                               1               157
# 20754                               1                 0
# 20755                               1                 0
# 20756                               1               363
# 20757                               1                 0
#
#        number_of_reviews_ltm             license rating bedrooms  beds  \
# 0                          0          No License   5.0         1     1
# 1                          2          No License  4.67         2     1
# 2                          6              Exempt  4.17         1     2
# 3                         12          No License  4.64         1     1
# 4                          3          No License  4.91    Studio     1
# ...                      ...                 ...    ...      ...   ...
# 20753                     12          No License  4.75         1     1
# 20754                      1          No License  4.46         1     2
# 20755                     27          No License  4.93         1     1
# 20756                      7          No License   5.0         1     1
# 20757                     62  OSE-STRREG-0000513  4.89         1     1
#
#                baths
# 0      Not specified
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 20753              1
# 20754              1
# 20755              1
# 20756              1
# 20757              1
#
# [20758 rows x 22 columns]

# %%
df.shape
# Out:
# (20758, 22)

# %%
df.info
# Out:
# <bound method DataFrame.info of                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20753            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20754             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20755            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20756  782661008019550832  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20757  566029911248687183  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# 0        7130382              Walter            Brooklyn        Clinton Hill
# 1       51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2      528871354              Joshua           Manhattan             Chelsea
# 3       19902271  John And Catherine           Manhattan  Washington Heights
# 4       61391963      Stay With Vibe           Manhattan         Murray Hill
# ...          ...                 ...                 ...                 ...
# 20753  186680487             Henry D           Manhattan     Lower East Side
# 20754    3237504               Aspen           Manhattan   Greenwich Village
# 20755  304317395                Jeff           Manhattan      Hell's Kitchen
# 20756  163083101             Marissa           Manhattan           Chinatown
# 20757   93827372             Glenroy              Queens            Rosedale
#
#         latitude  longitude        room_type  price  ...  last_review  \
# 0      40.683710 -73.964610     Private room   55.0  ...   2015-12-20
# 1      40.766610 -73.988100  Entire home/apt  144.0  ...   2023-05-01
# 2      40.750764 -73.994605  Entire home/apt  187.0  ...   2023-12-18
# 3      40.835600 -73.942500     Private room  120.0  ...   2023-09-17
# 4      40.751120 -73.978600  Entire home/apt   85.0  ...   2023-12-03
# ...          ...        ...              ...    ...  ...          ...
# 20753  40.711380 -73.991560     Private room   45.0  ...   2023-09-29
# 20754  40.730580 -74.000700  Entire home/apt  105.0  ...   2023-07-01
# 20755  40.757350 -73.993430  Entire home/apt  299.0  ...   2023-12-08
# 20756  40.713750 -73.991470  Entire home/apt  115.0  ...   2023-09-17
# 20757  40.658874 -73.728651     Private room  102.0  ...   2023-12-10
#
#        reviews_per_month calculated_host_listings_count  availability_365  \
# 0                   0.03                              1                 0
# 1                   0.24                            139               364
# 2                   1.67                              1               343
# 3                   1.38                              2               363
# 4                   0.24                            133               335
# ...                  ...                            ...               ...
# 20753               1.81                              1               157
# 20754               0.48                              1                 0
# 20755               2.09                              1                 0
# 20756               0.91                              1               363
# 20757               4.50                              1                 0
#
#        number_of_reviews_ltm             license  rating bedrooms beds  \
# 0                          0          No License    5.0         1    1
# 1                          2          No License   4.67         2    1
# 2                          6              Exempt   4.17         1    2
# 3                         12          No License   4.64         1    1
# 4                          3          No License   4.91    Studio    1
# ...                      ...                 ...     ...      ...  ...
# 20753                     12          No License   4.75         1    1
# 20754                      1          No License   4.46         1    2
# 20755                     27          No License   4.93         1    1
# 20756                      7          No License    5.0         1    1
# 20757                     62  OSE-STRREG-0000513   4.89         1    1
#
#                baths
# 0      Not specified
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 20753              1
# 20754              1
# 20755              1
# 20756              1
# 20757              1
#
# [20758 rows x 22 columns]>

# %%
pd.set_option('display.max_columns',85)

# %%
schema_df=pd.read_csv(csv_path)

# %%
schema_df
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                   ...                                                ...
# 20753            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20754             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20755            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20756  782661008019550832  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20757  566029911248687183  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# 0        7130382              Walter            Brooklyn        Clinton Hill
# 1       51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2      528871354              Joshua           Manhattan             Chelsea
# 3       19902271  John And Catherine           Manhattan  Washington Heights
# 4       61391963      Stay With Vibe           Manhattan         Murray Hill
# ...          ...                 ...                 ...                 ...
# 20753  186680487             Henry D           Manhattan     Lower East Side
# 20754    3237504               Aspen           Manhattan   Greenwich Village
# 20755  304317395                Jeff           Manhattan      Hell's Kitchen
# 20756  163083101             Marissa           Manhattan           Chinatown
# 20757   93827372             Glenroy              Queens            Rosedale
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      40.683710 -73.964610     Private room   55.0              30
# 1      40.766610 -73.988100  Entire home/apt  144.0              30
# 2      40.750764 -73.994605  Entire home/apt  187.0               2
# 3      40.835600 -73.942500     Private room  120.0              30
# 4      40.751120 -73.978600  Entire home/apt   85.0              30
# ...          ...        ...              ...    ...             ...
# 20753  40.711380 -73.991560     Private room   45.0              30
# 20754  40.730580 -74.000700  Entire home/apt  105.0              30
# 20755  40.757350 -73.993430  Entire home/apt  299.0              30
# 20756  40.713750 -73.991470  Entire home/apt  115.0              30
# 20757  40.658874 -73.728651     Private room  102.0               1
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      3  2015-12-20               0.03
# 1                      9  2023-05-01               0.24
# 2                      6  2023-12-18               1.67
# 3                    156  2023-09-17               1.38
# 4                     11  2023-12-03               0.24
# ...                  ...         ...                ...
# 20753                124  2023-09-29               1.81
# 20754                 56  2023-07-01               0.48
# 20755                 60  2023-12-08               2.09
# 20756                  7  2023-09-17               0.91
# 20757                 63  2023-12-10               4.50
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1                 0
# 1                                 139               364
# 2                                   1               343
# 3                                   2               363
# 4                                 133               335
# ...                               ...               ...
# 20753                               1               157
# 20754                               1                 0
# 20755                               1                 0
# 20756                               1               363
# 20757                               1                 0
#
#        number_of_reviews_ltm             license rating bedrooms  beds  \
# 0                          0          No License   5.0         1     1
# 1                          2          No License  4.67         2     1
# 2                          6              Exempt  4.17         1     2
# 3                         12          No License  4.64         1     1
# 4                          3          No License  4.91    Studio     1
# ...                      ...                 ...    ...      ...   ...
# 20753                     12          No License  4.75         1     1
# 20754                      1          No License  4.46         1     2
# 20755                     27          No License  4.93         1     1
# 20756                      7          No License   5.0         1     1
# 20757                     62  OSE-STRREG-0000513  4.89         1     1
#
#                baths
# 0      Not specified
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 20753              1
# 20754              1
# 20755              1
# 20756              1
# 20757              1
#
# [20758 rows x 22 columns]

# %%
df['minimum_nights'].unique
# Out:
# <bound method Series.unique of 0        30
# 1        30
# 2         2
# 3        30
# 4        30
#          ..
# 20753    30
# 20754    30
# 20755    30
# 20756    30
# 20757     1
# Name: minimum_nights, Length: 20758, dtype: int64>

# %%
df1=df['minimum_nights']>=30
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 20753     True
# 20754     True
# 20755     True
# 20756     True
# 20757    False
# Name: minimum_nights, Length: 20758, dtype: bool

# %%
df1
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 20753     True
# 20754     True
# 20755     True
# 20756     True
# 20757    False
# Name: minimum_nights, Length: 20758, dtype: bool

# %%
df1. to_csv('minimum_nights.csv')

# %%
df['price'].max()
# Out:
# 100000.0

# %%
df.head()
# Out:
#                    id                                               name  \
# 0             1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0  40.683710 -73.964610     Private room   55.0              30
# 1  40.766610 -73.988100  Entire home/apt  144.0              30
# 2  40.750764 -73.994605  Entire home/apt  187.0               2
# 3  40.835600 -73.942500     Private room  120.0              30
# 4  40.751120 -73.978600  Entire home/apt   85.0              30
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  3  2015-12-20               0.03
# 1                  9  2023-05-01               0.24
# 2                  6  2023-12-18               1.67
# 3                156  2023-09-17               1.38
# 4                 11  2023-12-03               0.24
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1                 0                      0
# 1                             139               364                      2
# 2                               1               343                      6
# 3                               2               363                     12
# 4                             133               335                      3
#
#       license rating bedrooms  beds          baths
# 0  No License   5.0         1     1  Not specified
# 1  No License  4.67         2     1              1
# 2      Exempt  4.17         1     2              1
# 3  No License  4.64         1     1              1
# 4  No License  4.91    Studio     1              1

# %%
df.tail()
# Out:
#                        id                                               name  \
# 20753            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20754             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20755            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20756  782661008019550832  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20757  566029911248687183  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20753  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20754    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20755  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20756  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20757   93827372   Glenroy              Queens           Rosedale  40.658874
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 20753 -73.991560     Private room   45.0              30                124
# 20754 -74.000700  Entire home/apt  105.0              30                 56
# 20755 -73.993430  Entire home/apt  299.0              30                 60
# 20756 -73.991470  Entire home/apt  115.0              30                  7
# 20757 -73.728651     Private room  102.0               1                 63
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 20753  2023-09-29               1.81                               1
# 20754  2023-07-01               0.48                               1
# 20755  2023-12-08               2.09                               1
# 20756  2023-09-17               0.91                               1
# 20757  2023-12-10               4.50                               1
#
#        availability_365  number_of_reviews_ltm             license rating  \
# 20753               157                     12          No License  4.75
# 20754                 0                      1          No License  4.46
# 20755                 0                     27          No License  4.93
# 20756               363                      7          No License   5.0
# 20757                 0                     62  OSE-STRREG-0000513  4.89
#
#       bedrooms  beds baths
# 20753        1     1     1
# 20754        1     2     1
# 20755        1     1     1
# 20756        1     1     1
# 20757        1     1     1

# %%
df.head(1)
# Out:
#         id                                        name  host_id host_name  \
# 0  1312228  Rental unit in Brooklyn · ★5.0 · 1 bedroom  7130382    Walter
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0            Brooklyn  Clinton Hill  40.68371  -73.96461  Private room   55.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                  3  2015-12-20               0.03
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1                 0                      0
#
#       license rating bedrooms  beds          baths
# 0  No License   5.0         1     1  Not specified

# %%
df[2:5]
# Out:
#                    id                                               name  \
# 2  971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 2  40.750764 -73.994605  Entire home/apt  187.0               2
# 3  40.835600 -73.942500     Private room  120.0              30
# 4  40.751120 -73.978600  Entire home/apt   85.0              30
#
#    number_of_reviews last_review  reviews_per_month  \
# 2                  6  2023-12-18               1.67
# 3                156  2023-09-17               1.38
# 4                 11  2023-12-03               0.24
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 2                               1               343                      6
# 3                               2               363                     12
# 4                             133               335                      3
#
#       license rating bedrooms  beds baths
# 2      Exempt  4.17         1     2     1
# 3  No License  4.64         1     1     1
# 4  No License  4.91    Studio     1     1

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
df.rating
# Out:
# 0         5.0
# 1        4.67
# 2        4.17
# 3        4.64
# 4        4.91
#          ...
# 20753    4.75
# 20754    4.46
# 20755    4.93
# 20756     5.0
# 20757    4.89
# Name: rating, Length: 20758, dtype: object

# %%
type(df['rating'])
# Out:
# pandas.core.series.Series

# %%
df[['id','rating','minimum_nights']]
# Out:
#                        id rating  minimum_nights
# 0                 1312228   5.0               30
# 1                45277537  4.67               30
# 2      971353993633883038  4.17                2
# 3                 3857863  4.64               30
# 4                40896611  4.91               30
# ...                   ...    ...             ...
# 20753            24736896  4.75               30
# 20754             2835711  4.46               30
# 20755            51825274  4.93               30
# 20756  782661008019550832   5.0               30
# 20757  566029911248687183  4.89                1
#
# [20758 rows x 3 columns]

# %%
df['rating'].min()
# Out:
# '1.75 '

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.075800e+04  2.075800e+04  20758.000000  20758.000000   20758.000000
# mean   3.034044e+17  1.749316e+08     40.726798    -73.939161     187.776616
# std    3.901216e+17  1.725541e+08      0.060294      0.061403    1022.797208
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.708808e+07  2.041738e+07     40.684150    -73.980710      80.000000
# 50%    4.993003e+07  1.087271e+08     40.722820    -73.949587     125.000000
# 75%    7.216019e+17  3.144102e+08     40.763098    -73.917460     199.000000
# max    1.054376e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20758.000000       20758.000000       20758.000000
# mean        28.558435          42.642596           1.257910
# std         33.536518          73.561654           1.904661
# min          1.000000           1.000000           0.010000
# 25%         30.000000           4.000000           0.210000
# 50%         30.000000          14.000000           0.650000
# 75%         30.000000          49.000000           1.800000
# max       1250.000000        1865.000000          75.490000
#
#        calculated_host_listings_count  availability_365  \
# count                    20758.000000      20758.000000
# mean                        18.844108        205.990317
# std                         70.910834        135.087768
# min                          1.000000          0.000000
# 25%                          1.000000         87.000000
# 50%                          2.000000        215.000000
# 75%                          5.000000        353.000000
# max                        713.000000        365.000000
#
#        number_of_reviews_ltm          beds
# count           20758.000000  20758.000000
# mean               10.852105      1.723721
# std                21.357071      1.212272
# min                 0.000000      1.000000
# 25%                 1.000000      1.000000
# 50%                 3.000000      1.000000
# 75%                15.000000      2.000000
# max              1075.000000     42.000000

# %%
df[df.minimum_nights>=20]
# Out:
#                        id                                               name  \
# 0                 1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1                45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 3                 3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4                40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 5                49584983  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# ...                   ...                                                ...
# 20752  897176430920178886  Rental unit in New York · 1 bedroom · 1 bed · ...
# 20753            24736896  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20754             2835711  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20755            51825274  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20756  782661008019550832  Rental unit in New York · ★5.0 · 1 bedroom · 1...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# 0        7130382              Walter            Brooklyn        Clinton Hill
# 1       51501835            Jeniffer           Manhattan      Hell's Kitchen
# 3       19902271  John And Catherine           Manhattan  Washington Heights
# 4       61391963      Stay With Vibe           Manhattan         Murray Hill
# 5       51501835            Jeniffer           Manhattan      Hell's Kitchen
# ...          ...                 ...                 ...                 ...
# 20752   15828752              Gideon           Manhattan             Midtown
# 20753  186680487             Henry D           Manhattan     Lower East Side
# 20754    3237504               Aspen           Manhattan   Greenwich Village
# 20755  304317395                Jeff           Manhattan      Hell's Kitchen
# 20756  163083101             Marissa           Manhattan           Chinatown
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0      40.68371  -73.96461     Private room   55.0              30
# 1      40.76661  -73.98810  Entire home/apt  144.0              30
# 3      40.83560  -73.94250     Private room  120.0              30
# 4      40.75112  -73.97860  Entire home/apt   85.0              30
# 5      40.75995  -73.99296  Entire home/apt  115.0              30
# ...         ...        ...              ...    ...             ...
# 20752  40.76452  -73.97792  Entire home/apt  140.0              35
# 20753  40.71138  -73.99156     Private room   45.0              30
# 20754  40.73058  -74.00070  Entire home/apt  105.0              30
# 20755  40.75735  -73.99343  Entire home/apt  299.0              30
# 20756  40.71375  -73.99147  Entire home/apt  115.0              30
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      3  2015-12-20               0.03
# 1                      9  2023-05-01               0.24
# 3                    156  2023-09-17               1.38
# 4                     11  2023-12-03               0.24
# 5                      5  2023-07-29               0.16
# ...                  ...         ...                ...
# 20752                  1  2023-07-31               0.19
# 20753                124  2023-09-29               1.81
# 20754                 56  2023-07-01               0.48
# 20755                 60  2023-12-08               2.09
# 20756                  7  2023-09-17               0.91
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1                 0
# 1                                 139               364
# 3                                   2               363
# 4                                 133               335
# 5                                 139               276
# ...                               ...               ...
# 20752                               1               267
# 20753                               1               157
# 20754                               1                 0
# 20755                               1                 0
# 20756                               1               363
#
#        number_of_reviews_ltm     license     rating bedrooms  beds  \
# 0                          0  No License       5.0         1     1
# 1                          2  No License      4.67         2     1
# 3                         12  No License      4.64         1     1
# 4                          3  No License      4.91    Studio     1
# 5                          2  No License       5.0         1     1
# ...                      ...         ...        ...      ...   ...
# 20752                      1  No License  No rating        1     1
# 20753                     12  No License      4.75         1     1
# 20754                      1  No License      4.46         1     2
# 20755                     27  No License      4.93         1     1
# 20756                      7  No License       5.0         1     1
#
#                baths
# 0      Not specified
# 1                  1
# 3                  1
# 4                  1
# 5                  1
# ...              ...
# 20752              1
# 20753              1
# 20754              1
# 20755              1
# 20756              1
#
# [17677 rows x 22 columns]

# %%
df['id'][df.beds==df['beds'].max()]
# Out:
# 19154    2261367
# Name: id, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20758, step=1)

# %%
df.set_index('id',inplace=True)

# %%
df
# Out:
#                                                                  name  \
# id
# 1312228                    Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 45277537            Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3857863             Rental unit in New York · ★4.64 · 1 bedroom · ...
# 40896611            Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...                                                               ...
# 24736896            Rental unit in New York · ★4.75 · 1 bedroom · ...
# 2835711             Rental unit in New York · ★4.46 · 1 bedroom · ...
# 51825274            Rental unit in New York · ★4.93 · 1 bedroom · ...
# 782661008019550832  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 566029911248687183  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#                       host_id           host_name neighbourhood_group  \
# id
# 1312228               7130382              Walter            Brooklyn
# 45277537             51501835            Jeniffer           Manhattan
# 971353993633883038  528871354              Joshua           Manhattan
# 3857863              19902271  John And Catherine           Manhattan
# 40896611             61391963      Stay With Vibe           Manhattan
# ...                       ...                 ...                 ...
# 24736896            186680487             Henry D           Manhattan
# 2835711               3237504               Aspen           Manhattan
# 51825274            304317395                Jeff           Manhattan
# 782661008019550832  163083101             Marissa           Manhattan
# 566029911248687183   93827372             Glenroy              Queens
#
#                          neighbourhood   latitude  longitude        room_type  \
# id
# 1312228                   Clinton Hill  40.683710 -73.964610     Private room
# 45277537                Hell's Kitchen  40.766610 -73.988100  Entire home/apt
# 971353993633883038             Chelsea  40.750764 -73.994605  Entire home/apt
# 3857863             Washington Heights  40.835600 -73.942500     Private room
# 40896611                   Murray Hill  40.751120 -73.978600  Entire home/apt
# ...                                ...        ...        ...              ...
# 24736896               Lower East Side  40.711380 -73.991560     Private room
# 2835711              Greenwich Village  40.730580 -74.000700  Entire home/apt
# 51825274                Hell's Kitchen  40.757350 -73.993430  Entire home/apt
# 782661008019550832           Chinatown  40.713750 -73.991470  Entire home/apt
# 566029911248687183            Rosedale  40.658874 -73.728651     Private room
#
#                     price  minimum_nights  number_of_reviews last_review  \
# id
# 1312228              55.0              30                  3  2015-12-20
# 45277537            144.0              30                  9  2023-05-01
# 971353993633883038  187.0               2                  6  2023-12-18
# 3857863             120.0              30                156  2023-09-17
# 40896611             85.0              30                 11  2023-12-03
# ...                   ...             ...                ...         ...
# 24736896             45.0              30                124  2023-09-29
# 2835711             105.0              30                 56  2023-07-01
# 51825274            299.0              30                 60  2023-12-08
# 782661008019550832  115.0              30                  7  2023-09-17
# 566029911248687183  102.0               1                 63  2023-12-10
#
#                     reviews_per_month  calculated_host_listings_count  \
# id
# 1312228                          0.03                               1
# 45277537                         0.24                             139
# 971353993633883038               1.67                               1
# 3857863                          1.38                               2
# 40896611                         0.24                             133
# ...                               ...                             ...
# 24736896                         1.81                               1
# 2835711                          0.48                               1
# 51825274                         2.09                               1
# 782661008019550832               0.91                               1
# 566029911248687183               4.50                               1
#
#                     availability_365  number_of_reviews_ltm  \
# id
# 1312228                            0                      0
# 45277537                         364                      2
# 971353993633883038               343                      6
# 3857863                          363                     12
# 40896611                         335                      3
# ...                              ...                    ...
# 24736896                         157                     12
# 2835711                            0                      1
# 51825274                           0                     27
# 782661008019550832               363                      7
# 566029911248687183                 0                     62
#
#                                license rating bedrooms  beds          baths
# id
# 1312228                     No License   5.0         1     1  Not specified
# 45277537                    No License  4.67         2     1              1
# 971353993633883038              Exempt  4.17         1     2              1
# 3857863                     No License  4.64         1     1              1
# 40896611                    No License  4.91    Studio     1              1
# ...                                ...    ...      ...   ...            ...
# 24736896                    No License  4.75         1     1              1
# 2835711                     No License  4.46         1     2              1
# 51825274                    No License  4.93         1     1              1
# 782661008019550832          No License   5.0         1     1              1
# 566029911248687183  OSE-STRREG-0000513  4.89         1     1              1
#
# [20758 rows x 21 columns]
