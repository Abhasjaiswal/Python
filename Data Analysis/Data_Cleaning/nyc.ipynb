# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

pd.set_option('display.max_columns',None)   #can used to display all the columns present in the dataframe 
#pd.set_option('display.max_rows',None)     # can be used to display all the rows present in the dataframe

# %%
read_csv=('2015_Street_Tree_Census_-_Tree_Data_20240127.csv')
df=pd.read_csv(read_csv,parse_dates=['created_at'])

# %%
df.head()
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711 2015-08-27         3           0   OnCurb  Alive   Fair
# 1   200540    315986 2015-09-03        21           0   OnCurb  Alive   Fair
# 2   204026    218365 2015-09-05         3           0   OnCurb  Alive   Good
# 3   204337    217969 2015-09-05        10           0   OnCurb  Alive   Good
# 4   189565    223043 2015-08-30        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple     NaN    NaN
# 1                   Quercus palustris          pin oak     NaN    NaN
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN
# 4                     Tilia americana  American linden     NaN    NaN
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# ...

# %%
df.dtypes
# Out:
# tree_id                      int64
# block_id                     int64
# created_at          datetime64[ns]
# tree_dbh                     int64
# stump_diam                   int64
# curb_loc                    object
# status                      object
# health                      object
# spc_latin                   object
# spc_common                  object
# steward                     object
# guards                      object
# sidewalk                    object
# user_type                   object
# problems                    object
# root_stone                  object
# root_grate                  object
# root_other                  object
# trunk_wire                  object
# trnk_light                  object
# trnk_other                  object
# brch_light                  object
# brch_shoe                   object
# brch_other                  object
# address                     object
# postcode                     int64
# zip_city                    object
# ...
