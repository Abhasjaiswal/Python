# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('mobiles.csv')

# %%
df.isnull().sum()
# Out:
# mobile_name        0
# price              0
# rating             0
# specs_score      155
# connectivity       0
# processor          0
# storage            0
# battery            0
# display            0
# camera             0
# extra_storage      3
# os                11
# brand              0
# dtype: int64

# %%
df.shape
# Out:
# (1020, 12)

# %%
df.isna().sum()
# Out:
# mobile_name        0
# price              0
# rating             0
# specs_score      155
# connectivity       0
# processor          0
# storage            0
# battery            0
# display            0
# camera             0
# extra_storage      3
# os                11
# dtype: int64

# %%
df.columns
# Out:
# Index(['mobile_name', 'price', 'rating', 'specs_score', 'connectivity',
#        'processor', 'storage', 'battery', 'display', 'camera', 'extra_storage',
#        'os'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mobile_name       object
# price             object
# rating           float64
# specs_score      float64
# connectivity      object
# processor         object
# storage           object
# battery           object
# display           object
# camera            object
# extra_storage     object
# os                object
# dtype: object

# %%
df[df.duplicated()]
# Out:
#        mobile_name    price  rating  specs_score  \
# 120  Lava Storm 5G  ₹13,499    4.65         81.0
#
#                            connectivity  \
# 120  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                         processor                   storage  \
# 120  Dimensity 6080, Octa Core, 2.4 GHz Processor  8 GB RAM, 128 GB inbuilt
#
#                                      battery  \
# 120  5000 mAh Battery with 33W Fast Charging
#
#                                                display  \
# 120  6.78 inches, 2400 x 1200 px, 120 Hz Display wi...
#
#                                           camera  \
# 120  50 MP + 8 MP Dual Rear & 16 MP Front Camera
#
#                         extra_storage           os
# 120  Memory Card Supported, upto 1 TB  Android v13

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                           mobile_name      price  rating  specs_score  \
# 0                        OPPO Reno 11    ₹29,990    4.70         86.0
# 1                      Poco X6 Pro 5G    ₹19,999    4.50         84.0
# 2       Xiaomi Redmi Note 13 Pro Plus    ₹31,999    4.35         87.0
# 3                    OPPO Reno 11 Pro    ₹40,990    4.75         88.0
# 4     Xiaomi Redmi Note 13 Pro Max 5G    ₹33,999    4.00         87.0
# ...                               ...        ...     ...          ...
# 1015                   POCO M3 Pro 5G    ₹12,390    4.50         75.0
# 1016                 Asus ROG Phone 6    ₹71,999    4.70         86.0
# 1017         iQOO 7 (8GB RAM + 256GB)    ₹25,499    4.05         84.0
# 1018                    Realme X7 Max    ₹23,999    4.55         84.0
# 1019               Xiaomi Mi Mix Fold  ₹1,09,990    4.55          NaN
#
#                                            connectivity  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1019 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mobile_name    1019 non-null   object
#  1   price          1019 non-null   object
#  2   rating         1019 non-null   float64
#  3   specs_score    864 non-null    float64
#  4   connectivity   1019 non-null   object
#  5   processor      1019 non-null   object
#  6   storage        1019 non-null   object
#  7   battery        1019 non-null   object
#  8   display        1019 non-null   object
#  9   camera         1019 non-null   object
#  10  extra_storage  1016 non-null   object
#  11  os             1008 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 103.5+ KB

# %%
df.isnull().sum()
# Out:
# mobile_name        0
# price              0
# rating             0
# specs_score      155
# connectivity       0
# processor          0
# storage            0
# battery            0
# display            0
# camera             0
# extra_storage      3
# os                11
# dtype: int64

# %%
df['mobile_name']
# Out:
# 0                          OPPO Reno 11
# 1                        Poco X6 Pro 5G
# 2         Xiaomi Redmi Note 13 Pro Plus
# 3                      OPPO Reno 11 Pro
# 4       Xiaomi Redmi Note 13 Pro Max 5G
#                      ...
# 1015                     POCO M3 Pro 5G
# 1016                   Asus ROG Phone 6
# 1017           iQOO 7 (8GB RAM + 256GB)
# 1018                      Realme X7 Max
# 1019                 Xiaomi Mi Mix Fold
# Name: mobile_name, Length: 1019, dtype: object

# %%
df.columns
# Out:
# Index(['mobile_name', 'price', 'rating', 'specs_score', 'connectivity',
#        'processor', 'storage', 'battery', 'display', 'camera', 'extra_storage',
#        'os'],
#       dtype='object')

# %%
df.drop(columns='os')
# Out:
#                           mobile_name      price  rating  specs_score  \
# 0                        OPPO Reno 11    ₹29,990    4.70         86.0
# 1                      Poco X6 Pro 5G    ₹19,999    4.50         84.0
# 2       Xiaomi Redmi Note 13 Pro Plus    ₹31,999    4.35         87.0
# 3                    OPPO Reno 11 Pro    ₹40,990    4.75         88.0
# 4     Xiaomi Redmi Note 13 Pro Max 5G    ₹33,999    4.00         87.0
# ...                               ...        ...     ...          ...
# 1015                   POCO M3 Pro 5G    ₹12,390    4.50         75.0
# 1016                 Asus ROG Phone 6    ₹71,999    4.70         86.0
# 1017         iQOO 7 (8GB RAM + 256GB)    ₹25,499    4.05         84.0
# 1018                    Realme X7 Max    ₹23,999    4.55         84.0
# 1019               Xiaomi Mi Mix Fold  ₹1,09,990    4.55          NaN
#
#                                            connectivity  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ...

# %%
df['brand'] = df['mobile_name'].str.split(' ', n=1, expand=True)[0]

# %%
df.head()
# Out:
#                        mobile_name    price  rating  specs_score  \
# 0                     OPPO Reno 11  ₹29,990    4.70         86.0
# 1                   Poco X6 Pro 5G  ₹19,999    4.50         84.0
# 2    Xiaomi Redmi Note 13 Pro Plus  ₹31,999    4.35         87.0
# 3                 OPPO Reno 11 Pro  ₹40,990    4.75         88.0
# 4  Xiaomi Redmi Note 13 Pro Max 5G  ₹33,999    4.00         87.0
#
#                                         connectivity  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            processor  \
# 0       Dimensity 8200, Octa Core, 3.1 GHz Processor
# 1  Dimensity 8300 Ultra, Octa Core, 3.35 GHz Proc...
# 2  Dimensity 7200 Ultra, Octa Core, 2.8 GHz Proce...
# ...

# %%
df['brand'].unique()
# Out:
# array(['OPPO', 'Poco', 'Xiaomi', 'Motorola', 'OnePlus', 'Vivo', 'iQOO',
#        'Samsung', 'Realme', 'Infinix', 'POCO', 'Apple', 'Nokia', 'Oppo',
#        'Tecno', 'itel', 'Nubia', 'Lava', 'Honor', 'Meizu', 'Google',
#        'Nothing', 'Asus', 'Huawei', 'Jio', 'Snexian', 'Tesla', 'Duoqin',
#        'Gionee', 'BlackZone', 'JIo', 'Sony', 'Ulefone', 'Itel',
#        'Blackview', 'iKall', 'Redmi', 'Letv', 'Namotel', 'Solana', 'MTR',
#        'LG', 'Docoss', 'Oukitel', 'Doogee', 'Cellecor', 'Fairphone',
#        'Unihertz', 'HTC', 'ZTE'], dtype=object)

# %%
df.columns
# Out:
# Index(['mobile_name', 'price', 'rating', 'specs_score', 'connectivity',
#        'processor', 'storage', 'battery', 'display', 'camera', 'extra_storage',
#        'os', 'brand'],
#       dtype='object')

# %%
df.drop(columns=['mobile_name','model'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.drop(columns=['mobile_name','model'],inplace=True)
#
# File ~/Desktop/Python/myenv/lib/python3.11/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
df.set_index('brand',inplace=True)

# %%
df.columns
# Out:
# Index(['price', 'rating', 'specs_score', 'connectivity', 'processor',
#        'storage', 'battery', 'display', 'camera', 'extra_storage', 'os'],
#       dtype='object')

# %%
df.drop(columns=['extra_storage','os'],inplace=True)

# %%
df
# Out:
#            price  rating  specs_score  \
# brand
# Apple  ₹1,59,900    4.20          NaN
# Apple    ₹92,999    4.75          NaN
# Apple  ₹1,56,900    4.25          NaN
# Apple    ₹48,999    4.55          NaN
# Apple  ₹1,30,990    4.15          NaN
# ...          ...     ...          ...
# itel      ₹1,559    4.20          NaN
# itel      ₹6,799    4.30          NaN
# itel      ₹6,489    4.35          NaN
# itel      ₹6,490    4.65          NaN
# itel      ₹1,499    4.60          NaN
#
#                                   connectivity  \
# brand
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                        ...
# itel            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1019 entries, OPPO to Xiaomi
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         1019 non-null   object
#  1   rating        1019 non-null   float64
#  2   specs_score   864 non-null    float64
#  3   connectivity  1019 non-null   object
#  4   processor     1019 non-null   object
#  5   storage       1019 non-null   object
#  6   battery       1019 non-null   object
#  7   display       1019 non-null   object
#  8   camera        1019 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 79.6+ KB

# %%
# Out:
# brand
# OPPO      86.0
# Poco      84.0
# Xiaomi    87.0
# OPPO      88.0
# Xiaomi    87.0
#           ...
# POCO      75.0
# Asus      86.0
# iQOO      84.0
# Realme    84.0
# Xiaomi     NaN
# Name: specs_score, Length: 1019, dtype: float64

# %%
df.sort_values(by='brand',inplace=True)

# %%
df
# Out:
#            price  rating  specs_score  \
# brand
# Apple  ₹1,59,900    4.20          NaN
# Apple    ₹92,999    4.75          NaN
# Apple  ₹1,56,900    4.25          NaN
# Apple    ₹48,999    4.55          NaN
# Apple  ₹1,30,990    4.15          NaN
# ...          ...     ...          ...
# itel      ₹1,559    4.20          NaN
# itel      ₹6,799    4.30          NaN
# itel      ₹6,489    4.35          NaN
# itel      ₹6,490    4.65          NaN
# itel      ₹1,499    4.60          NaN
#
#                                   connectivity  \
# brand
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                        ...
# itel            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# ...

# %%
df['specs_score'].fillna(df['specs_score'].mean())

# %%
df
# Out:
#            price  rating specs_score                             connectivity  \
# brand
# Apple  ₹1,59,900    4.20        None  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple    ₹92,999    4.75        None  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  ₹1,56,900    4.25        None  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple    ₹48,999    4.55        None  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# Apple  ₹1,30,990    4.15        None  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...          ...     ...         ...                                      ...
# itel      ₹1,559    4.20        None           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel      ₹6,799    4.30        None           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel      ₹6,489    4.35        None           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel      ₹6,490    4.65        None           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# itel      ₹1,499    4.60        None                                 Dual Sim
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1019 entries, Apple to itel
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         1019 non-null   object
#  1   rating        1019 non-null   float64
#  2   specs_score   1019 non-null   float64
#  3   connectivity  1019 non-null   object
#  4   processor     1019 non-null   object
#  5   storage       1019 non-null   object
#  6   battery       1019 non-null   object
#  7   display       1019 non-null   object
#  8   camera        1019 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 79.6+ KB
